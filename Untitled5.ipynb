# %% [markdown]
# <a href="https://colab.research.google.com/github/non733641-gif/ict_assignment/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
expense = []
budget = float(input("Enter budget for the month: "))

while True:
    print("\n--- Expense Tracker Menu ---")
    print("1. Add Expense")
    print("2. Monthly Summary")
    print("3. Category-wise Report")
    print("4. Budget Alert")
    print("5. Spending Insights")
    print("6. Exit")

    choice = input("Enter your choice: ")


    if choice == "1":
        date = input("Enter date (yyyy-mm-dd): ")
        cat = input("Enter category (Food, Travel, Shopping, etc.): ")
        amt = int(input("Enter the amount: "))

        expense.append({
            "date": date,
            "category": cat,
            "amount": amt
        })

        print("Expense added successfully.")


    elif choice == "2":
        total = 0
        for i in expense:
            total += i["amount"]
        print(f"Total Monthly Spending: {total}")


    elif choice == "3":
        cat_tot = {}

        for i in expense:
            if i["category"] in cat_tot:
                cat_tot[i["category"]] += i["amount"]
            else:
                cat_tot[i["category"]] = i["amount"]

        print("\nCategory-wise Spending:")
        for cat, amt in cat_tot.items():
            print(f"{cat}: {amt}")


    elif choice == "4":
        tot = 0
        for i in expense:
            tot += i["amount"]

        if tot > budget:
            print("⚠ Monthly budget exceeded!")
        else:
            print("You are within your budget.")


    elif choice == "5":
        if len(expense) == 0:
            print("No expenses recorded.")
            continue


        day_total = {}
        for i in expense:
            if i["date"] in day_total:
                day_total[i["date"]] += i["amount"]
            else:
                day_total[i["date"]] = i["amount"]

        highest_day = ""
        highest_amount = 0
        for day in day_total:
            if day_total[day] > highest_amount:
                highest_amount = day_total[day]
                highest_day = day


        category_total = {}
        for i in expense:
            if i["category"] in category_total:
                category_total[i["category"]] += i["amount"]
            else:
                category_total[i["category"]] = i["amount"]

        dominant_category = ""
        max_spent = 0
        for cat in category_total:
            if category_total[cat] > max_spent:
                max_spent = category_total[cat]
                dominant_category = cat

        print(f"Highest spending day: {highest_day} (Amount: {highest_amount})")
        print(f"Dominant spending category: {dominant_category} (Amount: {max_spent})")


        avg_spending = 0
        for i in expense:
            avg_spending += i["amount"]
        avg_spending /= len(expense)

        print(f"Average Expense Amount: {avg_spending}")

        for i in expense:
            if i["amount"] > avg_spending:
                print(f"High spending detected on {i['date']} in {i['category']}")


    elif choice == "6":
        print("Exiting Expense Tracker. Goodbye!")
        break

    else:
        print("Invalid choice. Please try again.")
# Out:
# Enter budget for the month: 64237092434790237
#
# --- Expense Tracker Menu ---
# 1. Add Expense
# 2. Monthly Summary
# 3. Category-wise Report
# 4. Budget Alert
# 5. Spending Insights
# 6. Exit
# Enter your choice: 1
# Enter date (yyyy-mm-dd): 2007-08-01
# Enter category (Food, Travel, Shopping, etc.): travel
# Enter the amount: 3947654837
# Expense added successfully.
#
# --- Expense Tracker Menu ---
# 1. Add Expense
# 2. Monthly Summary
# 3. Category-wise Report
# 4. Budget Alert
# 5. Spending Insights
# 6. Exit
# Enter your choice: 1
# Enter date (yyyy-mm-dd): 2006-11-14
# Enter category (Food, Travel, Shopping, etc.): travel
# Enter the amount: 82746518
# Expense added successfully.
#
# --- Expense Tracker Menu ---
# 1. Add Expense
# 2. Monthly Summary
# 3. Category-wise Report
# 4. Budget Alert
# 5. Spending Insights
# 6. Exit
# Enter your choice: 2
# Total Monthly Spending: 4030401355
#
# --- Expense Tracker Menu ---
# 1. Add Expense
# 2. Monthly Summary
# 3. Category-wise Report
# 4. Budget Alert
# 5. Spending Insights
# 6. Exit
# Enter your choice: 3
#
# Category-wise Spending:
# travel: 4030401355
#
# --- Expense Tracker Menu ---
# 1. Add Expense
# 2. Monthly Summary
# 3. Category-wise Report
# 4. Budget Alert
# 5. Spending Insights
# 6. Exit
# Enter your choice: 4
# You are within your budget.
#
# --- Expense Tracker Menu ---
# 1. Add Expense
# 2. Monthly Summary
# 3. Category-wise Report
# 4. Budget Alert
# 5. Spending Insights
# 6. Exit
# Enter your choice: 5
# Highest spending day: 2007-08-01 (Amount: 3947654837)
# Dominant spending category: travel (Amount: 4030401355)
# Average Expense Amount: 2015200677.5
# High spending detected on 2007-08-01 in travel
#
# --- Expense Tracker Menu ---
# 1. Add Expense
# 2. Monthly Summary
# 3. Category-wise Report
# 4. Budget Alert
# 5. Spending Insights
# 6. Exit
# Enter your choice: 6
# Exiting Expense Tracker. Goodbye!
