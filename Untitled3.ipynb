# %% [markdown]
# <a href="https://colab.research.google.com/github/non733641-gif/ict_assignment/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def maximum(x,y,z):
    if(x>y):
        if(x>z):
            return x
        else:
            return z
    else:
        if(y>z):
            return y
        else:
            return z
a=int(input('enter the first number'))
b=int(input('enter the second number'))
c=int(input('enter the third number'))
maximum(a,b,c)
# Out:
# enter the first number54
# enter the second number56
# enter the third number76
# 76

# %%
l=[18, 12, 30,10, 7]

sum(l)
# Out:
# 77

# %%
l=[]
n=int(input("enter no to be inserted:"))
for i in n:
  l.append(n)
